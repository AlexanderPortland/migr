# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib.colors import LogNorm, Normalize
import sklearn
import time
import datetime
import joblib
import warnings
from sklearn.model_selection import ParameterGrid
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
data = [['last_year', 10.343981557029045],
        ['zero', 25.79585999597185],
        ['train_mean', 25.78954429261217],
        ['XGBoost', 13.238935694425836],
        ['XGBoost', 11.56658284379576],
        ['XGBoost', 9.815434282889152],
        ['XGBoost', 11.276301956704552],
        ['XGBoost', 10.26521592121377],
        ['LinearSVR', 9.00368299476908],
        ['RFR', 7.478723543421034],
        ['RFR', 7.622241359737829],
        ['RFR', 8.370817501792358],
        ['RFR', 8.20817501792358],
        ['RFR', 8],
        ['Ridge', 8.302734151341832],
        ['Poly', 6.83297972421315],
            ]
tests = pd.DataFrame(data, columns=['model_name', 'model_score'])

# %%
from matplotlib import rc, rcParams
sns.reset_defaults()
#sns.set(rc={'figure.figsize':(11.7,8.27)})
fig_title = "model_scores"
sns.catplot(data=tests, y="model_name", x="model_score", height=4, aspect=1.2, orient="h", kind="swarm", sharey=False, size=5, color='red')
#fig, ax = plt.subplots()
plt.gca().set_xlim(0, 30)
plt.xlabel('RMSE [people]')
#plt.gca().xaxis.label.set_color('white')
#plt.gca().tick_params(axis='x', colors='white')
#plt.gca().spines['bottom'].set_color('white')
plt.savefig("../figures/" + fig_title, bbox_inches="tight", pad_inches=0.4, dpi=300, transparent=False)
plt.show()
